# %%
import pandas as pd
import os
import openai
from typing import List, Dict, Optional
import json
from datetime import datetime

import textwrap

# %%
# use open ai model to generate a story about a city

# Set the API key directly
openai_key = "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"

chat_model = "gpt-3.5-turbo"

# %%
# Set up API key
openai.api_key = openai_key  # This was missing

# define function to query openai
def query_openai(prompt, model=chat_model):
    try:
        response = openai.chat.completions.create(
            model=model,  # Now you can specify different models
            messages=[
                {"role": "system", "content": "You are a knowledgeable guide summarizing origins, importance, major battles or wars, and famous people for multiple cities, focusing on salient points. You summary must factor in that the person has cycled through all these towns and you must respond adequantely."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=500,
            temperature=0.7
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {str(e)}"

# %%
# Test the function
prompt = "The Hague"
response = query_openai(prompt)
print(textwrap.fill(response, width=100))
# Out:
# The Hague is the political capital of the Netherlands and is known for being home to the Dutch
# government, parliament, and the monarch. It is also the location of many international
# organizations, such as the International Court of Justice and the International Criminal Court. The
# city has a rich history, dating back to the 13th century, and is known for its beautiful
# architecture, including the Binnenhof, a medieval castle housing the Dutch parliament. The Hague has
# been the site of many important historical events, including the signing of the Treaty of The Hague
# in 1648, which ended the Eighty Years' War between Spain and the Dutch Republic. Famous people
# associated with The Hague include the Dutch painter Johannes Vermeer and the philosopher Baruch
# Spinoza.

# %%
route_locations = pd.DataFrame(
    {
        "country": ["The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands", "The Netherlands"],
        "towns": ["Segbroek",  "Kraayenstein", "Kwintsheul", "Schipluiden", "Berkel en Rodenrijs", "Pijnacker", "Leidschendam", "Marlot", "Haagse Bos"],
            }
)

# %%
route_locations
# Out:
#            country                towns
# 0  The Netherlands             Segbroek
# 1  The Netherlands         Kraayenstein
# 2  The Netherlands           Kwintsheul
# 3  The Netherlands          Schipluiden
# 4  The Netherlands  Berkel en Rodenrijs
# 5  The Netherlands            Pijnacker
# 6  The Netherlands         Leidschendam
# 7  The Netherlands               Marlot
# 8  The Netherlands           Haagse Bos

# %%
# Only join unique town names, exclude country
all_unique_towns = route_locations["towns"].unique()
joined_string = ", ".join(map(str, all_unique_towns))
print("All unique towns joined into one string:")
print(textwrap.fill(joined_string, width=80))
# Out:
# All unique towns joined into one string:
# Segbroek, Kraayenstein, Kwintsheul, Schipluiden, Berkel en Rodenrijs, Pijnacker,
# Leidschendam, Marlot, Haagse Bos

# %%
def query_2(city_list, model=chat_model):
    """
    Generate a story about a cyclist's journey through a list of cities.
    city_list: list of city/town names or a comma-separated string.
    """
    if isinstance(city_list, list):
        cities = ", ".join(city_list)
    else:
        cities = city_list

    prompt = (
    f"Retell the cyclist's journey as if this was the dutch golden age, starting and ending at the first of {cities}"
    "weaving a vivid narrative of the route, key historic events, and notable figures tied to the cities."
    "Do not repeat the cities like reading a book. Tell the story as if you reader where actually there!"
)
    try:
        response = openai.chat.completions.create(
            model=model,
            messages=[
                {"role": "user", "content": prompt}
            ],
            max_tokens=500,
            temperature=0.2
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {str(e)}"

# %%
print(textwrap.fill(query_2(all_unique_towns), width=80))
# Out:
# The cyclist embarked on their journey from the bustling city of Segbroek, a hub
# of trade and commerce during the Dutch Golden Age. As they pedaled through the
# picturesque countryside, they passed by the quaint village of Kraayenstein,
# known for its thriving farming community.  Continuing on their path, the cyclist
# made their way through Kwintsheul, a town famous for its beautiful tulip fields
# that were in full bloom during the springtime. They then arrived in Schipluiden,
# a historic town with charming cobblestone streets and centuries-old windmills.
# Next, the cyclist pedaled through Berkel en Rodenrijs, a town that was once a
# strategic stronghold during the Eighty Years' War. They then passed through
# Pijnacker, a town known for its traditional Dutch architecture and picturesque
# canals.  As they approached Leidschendam, the cyclist marveled at the stunning
# views of the Vliet River and the historic buildings that lined its banks. They
# then made their way through Marlot, a peaceful neighborhood surrounded by lush
# greenery and grand estates.  Finally, the cyclist reached the majestic Haagse
# Bos, a sprawling forest that was a favorite hunting ground of the Dutch
# nobility. As they completed their journey back to Segbroek, the cyclist couldn't
# help but reflect on the rich history and beauty of the Dutch Golden Age that
# surrounded them at every turn.
